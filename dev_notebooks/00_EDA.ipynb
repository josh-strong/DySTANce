# %%
import pandas as pd
import glob
import os
from pathlib import Path

# Get repository root directory
# Try multiple methods to find the repo root
cwd = Path.cwd()
if (cwd / 'data').exists():
    REPO_ROOT = cwd
elif (cwd.parent / 'data').exists():
    REPO_ROOT = cwd.parent
else:
    # Fallback: assume we're in dev_notebooks and go up one level
    REPO_ROOT = cwd.parent

# %% [markdown]
# ### Findings:
#
# -- Hernia, mass, nodule, Fibrosis, Emphysema, Pneumothorax, Infiltration only have 0 labels in tr/val/test

# %%
# Investigate how good the tools are at predicting the labels
tr_df = pd.read_csv(REPO_ROOT / 'data' / 'openi' / 'labels' / 'Train.csv')
tr_df['id'] = tr_df['id'].apply(lambda x: str(x) + '.jpg')
tr_df.set_index('id', inplace=True)

tool_pred_csvs = glob.glob(str(REPO_ROOT / 'data' / 'openi' / 'predictions' / '*_train.csv'))

tool_metrics = {}
for tool in tool_pred_csvs:
    tool_name = tool.split('/')[-1][:-10]
    preds_df = pd.read_csv(tool).set_index('filename')
    # Check which columns have all values equal to 0.5
    cols_all_05 = [col for col in preds_df.columns if (preds_df[col] == 0.5).all()]
    preds_df.drop(cols_all_05, axis=1, inplace=True)
    preds_df = (preds_df > 0.5).astype(int)
    acc = (tr_df.loc[preds_df.index, preds_df.columns].values.flatten() == preds_df.values.flatten()).mean()

    tool_metrics[tool_name] = {
        'cols_doesnt_predict': cols_all_05,
        'acc': acc,
    }

# %%
tool_metrics
# Out:
# {'resnet_mgca_pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9494270435446907)},
#  'densenet121_res224_chex': {'cols_doesnt_predict': ['Infiltration',
#    'Emphysema',
#    'Fibrosis',
#    'Pleural_Thickening',
#    'Nodule',
#    'Mass',
#    'Hernia'],
#   'acc': np.float64(0.6384054448225571)},
#  'densenet121_res224_all': {'cols_doesnt_predict': [],
#   'acc': np.float64(0.6884135472370766)},
#  'densenet_medical_mae_pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9497326203208556)},
#  'densenet_mocov2_pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9493506493506494)},
#  'densenet121_res224_mimic_nb': {'cols_doesnt_predict': ['Infiltration',
#    'Emphysema',
#    'Fibrosis',
#    'Pleural_Thickening',
#    'Nodule',
#    'Mass',
#    'Hernia'],
#   'acc': np.float64(0.4215848322800195)},
#  'densenet121_res224_nih': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.6157372039724981)},
#  'resnet_biovil_pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9495034377387318)},
#  'densenet121_res224_mimic_ch': {'cols_doesnt_predict': ['Infiltration',
#    'Emphysema',
#    'Fibrosis',
#    'Pleural_Thickening',
#    'Nodule',
#    'Mass',
#    'Hernia'],
#   'acc': np.float64(0.31161886242100145)},
#  'densenet121_res224_rsna': {'cols_doesnt_predict': ['Atelectasis',
#    'Consolidation',
#    'Infiltration',
#    'Pneumothorax',
#    'Edema',
#    'Emphysema',
#    'Fibrosis',
#    'Effusion',
#    'Pleural_Thickening',
#    'Cardiomegaly',
#    'Nodule',
#    'Mass',
#    'Hernia',
#    'Lung Lesion',
#    'Fracture',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.6727272727272727)},
#  'evax_base_cxr__pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9488158899923606)},
#  'densenet121_res224_pc': {'cols_doesnt_predict': ['Lung Lesion',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.6813547237076649)},
#  'evax_small_chexpert_pt_openi': {'cols_doesnt_predict': ['Infiltration',
#    'Pneumothorax',
#    'Emphysema',
#    'Fibrosis',
#    'Pneumonia',
#    'Pleural_Thickening',
#    'Nodule',
#    'Mass',
#    'Hernia',
#    'Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.8701604278074866)},
#  'evax_tiny_cxr__pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9500381970970206)},
#  'evax_small_cxr__pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9504201680672268)},
#  'evax_tiny_chexpert_pt_openi': {'cols_doesnt_predict': ['Infiltration',
#    'Pneumothorax',
#    'Emphysema',
#    'Fibrosis',
#    'Pneumonia',
#    'Pleural_Thickening',
#    'Nodule',
#    'Mass',
#    'Hernia',
#    'Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.8703743315508021)},
#  'resnet50_res512_all': {'cols_doesnt_predict': ['Lung Lesion',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9239973262032085)},
#  'resnet_medklip_pt_openi': {'cols_doesnt_predict': ['Lung Lesion',
#    'Fracture',
#    'Lung Opacity',
#    'Enlarged Cardiomediastinum'],
#   'acc': np.float64(0.9496562261268143)}}

# %%
# Check which columns have all values equal to 0.5
cols_all_05 = [col for col in preds_df.columns if (preds_df[col] == 0.5).all()]
cols_all_05
# Out:
# []

# %%
tr_df = pd.read_csv(REPO_ROOT / 'data' / 'openi' / 'labels' / 'Train.csv').set_index('id')
val_df = pd.read_csv(REPO_ROOT / 'data' / 'openi' / 'labels' / 'Valid.csv').set_index('id')
te_df = pd.read_csv(REPO_ROOT / 'data' / 'openi' / 'labels' / 'Test.csv').set_index('id')

# %%
for col in tr_df.columns:
    print(f"Pathology: {col}")
    print(f"tr: {tr_df[col].value_counts()}")
    print(f"val: {val_df[col].value_counts()}")
    print(f"te: {te_df[col].value_counts()}")
    print('-----')
# Out:
# Pathology: Atelectasis
# tr: Atelectasis
# 0    820
# 1    115
# Name: count, dtype: int64
# val: Atelectasis
# 0    235
# 1     29
# Name: count, dtype: int64
# te: Atelectasis
# 0    140
# 1     16
# Name: count, dtype: int64
# -----
# Pathology: Consolidation
# tr: Consolidation
# 0    907
# 1     28
# Name: count, dtype: int64
# val: Consolidation
# 0    254
# 1     10
# Name: count, dtype: int64
# te: Consolidation
# 0    148
# 1      8
# Name: count, dtype: int64
# -----
# Pathology: Infiltration
# tr: Infiltration
# 0    935
# Name: count, dtype: int64
# val: Infiltration
# 0    264
# Name: count, dtype: int64
# te: Infiltration
# 0    156
# Name: count, dtype: int64
# -----
# Pathology: Pneumothorax
# tr: Pneumothorax
# 0    907
# 1     28
# Name: count, dtype: int64
# val: Pneumothorax
# 0    258
# 1      6
# Name: count, dtype: int64
# te: Pneumothorax
# 0    156
# Name: count, dtype: int64
# -----
# Pathology: Edema
# tr: Edema
# 0    919
# 1     16
# Name: count, dtype: int64
# val: Edema
# 0    260
# 1      4
# Name: count, dtype: int64
# te: Edema
# 0    154
# 1      2
# Name: count, dtype: int64
# -----
# Pathology: Emphysema
# tr: Emphysema
# 0    935
# Name: count, dtype: int64
# val: Emphysema
# 0    264
# Name: count, dtype: int64
# te: Emphysema
# 0    156
# Name: count, dtype: int64
# -----
# Pathology: Fibrosis
# tr: Fibrosis
# 0    935
# Name: count, dtype: int64
# val: Fibrosis
# 0    264
# Name: count, dtype: int64
# te: Fibrosis
# 0    156
# Name: count, dtype: int64
# -----
# Pathology: Effusion
# tr: Effusion
# 0    859
# 1     76
# Name: count, dtype: int64
# val: Effusion
# 0    241
# 1     23
# Name: count, dtype: int64
# te: Effusion
# 0    152
# 1      4
# Name: count, dtype: int64
# -----
# Pathology: Pneumonia
# tr: Pneumonia
# 0    919
# 1     16
# Name: count, dtype: int64
# val: Pneumonia
# 0    260
# 1      4
# Name: count, dtype: int64
# te: Pneumonia
# 0    149
# 1      7
# Name: count, dtype: int64
# -----
# Pathology: Pleural_Thickening
# tr: Pleural_Thickening
# 0    912
# 1     23
# Name: count, dtype: int64
# val: Pleural_Thickening
# 0    260
# 1      4
# Name: count, dtype: int64
# te: Pleural_Thickening
# 0    150
# 1      6
# Name: count, dtype: int64
# -----
# Pathology: Cardiomegaly
# tr: Cardiomegaly
# 0    570
# 1    365
# Name: count, dtype: int64
# val: Cardiomegaly
# 0    160
# 1    104
# Name: count, dtype: int64
# te: Cardiomegaly
# 0    105
# 1     51
# Name: count, dtype: int64
# -----
# Pathology: Nodule
# tr: Nodule
# 0    935
# Name: count, dtype: int64
# val: Nodule
# 0    264
# Name: count, dtype: int64
# te: Nodule
# 0    156
# Name: count, dtype: int64
# -----
# Pathology: Mass
# tr: Mass
# 0    935
# Name: count, dtype: int64
# val: Mass
# 0    264
# Name: count, dtype: int64
# te: Mass
# 0    156
# Name: count, dtype: int64
# -----
# Pathology: Hernia
# tr: Hernia
# 0    935
# Name: count, dtype: int64
# val: Hernia
# 0    264
# Name: count, dtype: int64
# te: Hernia
# 0    156
# Name: count, dtype: int64
# -----
# Pathology: Lung Lesion
# tr: Lung Lesion
# 0    836
# 1     99
# Name: count, dtype: int64
# val: Lung Lesion
# 0    240
# 1     24
# Name: count, dtype: int64
# te: Lung Lesion
# 0    141
# 1     15
# Name: count, dtype: int64
# -----
# Pathology: Fracture
# tr: Fracture
# 0    850
# 1     85
# Name: count, dtype: int64
# val: Fracture
# 0    243
# 1     21
# Name: count, dtype: int64
# te: Fracture
# 0    150
# 1      6
# Name: count, dtype: int64
# -----
# Pathology: Lung Opacity
# tr: Lung Opacity
# 0    555
# 1    380
# Name: count, dtype: int64
# val: Lung Opacity
# 0    148
# 1    116
# Name: count, dtype: int64
# te: Lung Opacity
# 0    84
# 1    72
# Name: count, dtype: int64
# -----
# Pathology: Enlarged Cardiomediastinum
# tr: Enlarged Cardiomediastinum
# 0    826
# 1    109
# Name: count, dtype: int64
# val: Enlarged Cardiomediastinum
# 0    234
# 1     30
# Name: count, dtype: int64
# te: Enlarged Cardiomediastinum
# 0    135
# 1     21
# Name: count, dtype: int64
# -----
